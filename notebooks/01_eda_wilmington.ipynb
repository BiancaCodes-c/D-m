# %% [markdown]
# # Wilmington EDAExploratory notebook for weather, air quality, and water temperature signals.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('../data/db/dheghom.db')
pd.read_sql('SELECT * FROM snapshots', conn)
